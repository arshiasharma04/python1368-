# %% [markdown]
# ![explorate.png](attachment:explorate.png)

# %% [markdown]
# ## Python is an Object-Oriented & Functional Programming Language

# %% [markdown]
# ## Every variable in Python is an Object ##

# %% [markdown]
# ## Variables-Values & Types

# %% [markdown]
# ### Primitive Data Types
# **int**<br>
# **float**<br>
# **complex**<br>
# **boolean**<br>
# **datetime**

# %% [markdown]
# ### Sequence Data Types
# **string**<br>
# **list**<br>
# **tuple**<br>
# **dictionary**<br>
# **set**<br>
# **frozenset**<br>
# **bytes**<br>
# **bytearray**<br>

# %% [markdown]
# ## typecasting

# %%
#int
a=16467984678934679834678934678934756893457698347568934769843769834678934679845767534
b=98457698457698347689439863467983475689345768934756893759863756873546734986789375689347568934768945

# %%
a*b
# Out:
# 1621399869724547046212922267524636293005543893044708498204460122754100779802438041668792505373759107876895340185943734056114483372974074501081780508128222839341899059598192472431630

# %%
a=-4573984759834759837458934759837459837598375983475983745

# %%
-a
# Out:
# 4573984759834759837458934759837459837598375983475983745

# %%
-1**2
# Out:
# -1

# %%
#float

# %%
a=1.34573984579384753984579834

# %%
#complex

# %%
a=12.4-9.5j

# %%
a.real
# Out:
# 12.4

# %%
a.imag
# Out:
# -9.5

# %%
a.conjugate().conjugate()
# Out:
# (12.4-9.5j)

# %%
a=True
b=False

# %%
23.56+345.67
# Out:
# 369.23

# %%
23>34
# Out:
# False

# %%
if b:print("Ya its True")

# %%
#datetime

# %%
myBirthDate="10---10/1980"

# %%
print(type(myBirthDate))
# Out:
# <class 'str'>

# %%
#module or package or library

# %%
import math   #An Example

# %%
math.sqrt(16)
# Out:
# 4.0

# %%
import datetime

# %%
myBdate=datetime.datetime(2022,10,10)

# %%
type(myBdate)
# Out:
# datetime.datetime

# %%
current=datetime.datetime.now()

# %%
current.year
# Out:
# 2022

# %%
#String

# %%
mydata=input()
# Out:
# df gsdf gsd g dsg 578345683 @#$#$#$%$^

# %%
print(mydata)
# Out:
# df gsdf gsd g dsg 578345683 @#$#$#$%$^

# %%
len(mydata)
# Out:
# 38

# %%
# Mutable  |  Ordered    |  Indexed (subscriptable)

# %%
# They all are heterogeneous

# %%
a="12.5-6.7j"   #String are immutable, indexed, Ordered

# %%
a[8]="J"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [139], line 1
# ----> 1 a[8]="J"
#
# TypeError: 'str' object does not support item assignment

# %%
print(a)
# Out:
# 12.5-6.7j

# %%
#List

# %%
a=["a",12,34.56,56+7j,True,datetime.datetime(2022,11,10)]

# %%
len(a)
# Out:
# 6

# %%
a[5]=546875467495769457698567895764985769845768946767

# %%
print(a)
# Out:
# ['a', 12, 34.56, (56+7j), True, 546875467495769457698567895764985769845768946767]

# %%
# Lists are Mutable, indexed, ordered

# %%
a=(12,34,566.67)

# %%
type(a)
# Out:
# tuple

# %%
a[0]=1234
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [152], line 1
# ----> 1 a[0]=1234
#
# TypeError: 'tuple' object does not support item assignment

# %%
print(a)
# Out:
# (12, 34, 566.67)

# %%
a=input()
# Out:
# Chitkara University

# %%
print(a)
# Out:
# Chitkara University

# %%
a=12,23

# %%
type(a)
# Out:
# tuple

# %%
print(a)
# Out:
# (12, 23)

# %%
a,b=12,(23,34)

# %%
a
# Out:
# 12

# %%
b
# Out:
# (23, 34)

# %%
a={123,223,3343,123}

# %%
type(a)
# Out:
# set

# %%
print(a)
# Out:
# {223, 123, 3343}

# %%
a[0]=345
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [182], line 1
# ----> 1 a[0]=345
#
# TypeError: 'set' object does not support item assignment

# %%
a=frozenset({1,2,3,4})

# %%
a[0]=234
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [187], line 1
# ----> 1 a[0]=234
#
# TypeError: 'frozenset' object does not support item assignment

# %%
s=bytes(12)

# %%
print(s)
# Out:
# b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'

# %%
s[0]=1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [191], line 1
# ----> 1 s[0]=1
#
# TypeError: 'bytes' object does not support item assignment

# %%
s=bytearray(10)

# %%
print(s)
# Out:
# bytearray(b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00')

# %%
s[0]
# Out:
# 0

# %%
s[0]=1

# %%
print(s)
# Out:
# bytearray(b'\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00')

# %%
a={100:'a',101:'b',102:'c'}    #Dictionary

# %%
a[100]
# Out:
# 'a'
